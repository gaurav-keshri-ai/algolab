# %% [markdown]
# <a href="https://colab.research.google.com/github/gaurav-keshri-ai/algolab/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
# Load the Python libraries
import matplotlib.pyplot as plt

# %%
# Prob_1

def add_two_numbers(a, b):
    return a + b

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
#Prob_2:Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
#similar to example-1, also plot the graph (eg. even_odd )
import matplotlib.pyplot as plt

# Function with constant time complexity O(1)
def check_number(num):
    if num > 0:
        return "Positive"
    elif num < 0:
        return "Negative"
    else:
        return "Zero"

# Test inputs
numbers = [-10, -5, 0, 5, 10]
results = [check_number(n) for n in numbers]

# Print results
for n, r in zip(numbers, results):
    print(f"{n} -> {r}")

# Plotting the graph
plt.figure(figsize=(6,4))
plt.scatter(numbers, results, color='blue', s=100)
plt.title("Constant Time Complexity Example: Positive/Negative/Zero")
plt.xlabel("Input Number")
plt.ylabel("Result Category")
plt.grid(True)
plt.show()
# Out:
# -10 -> Negative
# -5 -> Negative
# 0 -> Zero
# 5 -> Positive
# 10 -> Positive

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
#Prob_3:Take another example and write the code that runs in linear amount of time no matter what is the size of input..
#similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)

import matplotlib.pyplot as plt
import random
import time

# Function with linear time complexity O(n)
def count_positive_elements(arr):
    count = 0
    for num in arr:   # Loop runs n times
        if num > 0:
            count += 1
    return count

# Test with different input sizes
input_sizes = [10, 100, 1000, 5000, 10000]
execution_times = []

for size in input_sizes:
    arr = [random.randint(-100, 100) for _ in range(size)]
    start = time.time()
    count_positive_elements(arr)
    end = time.time()
    execution_times.append(end - start)

# Print results
for size, t in zip(input_sizes, execution_times):
    print(f"Input size: {size}, Execution time: {t:.6f} seconds")

# Plotting the graph
plt.figure(figsize=(6,4))
plt.plot(input_sizes, execution_times, marker='o', color='green')
plt.title("Linear Time Complexity Example: Count Elements > 0")
plt.xlabel("Input Size (n)")
plt.ylabel("Execution Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# Input size: 10, Execution time: 0.000003 seconds
# Input size: 100, Execution time: 0.000005 seconds
# Input size: 1000, Execution time: 0.000040 seconds
# Input size: 5000, Execution time: 0.000201 seconds
# Input size: 10000, Execution time: 0.000603 seconds

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
#Prob_4 Take Suitable example and write function that runs in logarithic time. plot graph as well similar to above example.
import matplotlib.pyplot as plt
import random
import time

# Function with logarithmic time complexity O(log n)
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return True
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return False

# Test with different input sizes
input_sizes = [10, 100, 1000, 5000, 10000, 50000]
execution_times = []

for size in input_sizes:
    arr = sorted(random.sample(range(size*2), size))  # sorted list
    target = random.choice(arr)  # pick a random element to search
    start = time.time()
    binary_search(arr, target)
    end = time.time()
    execution_times.append(end - start)

# Print results
for size, t in zip(input_sizes, execution_times):
    print(f"Input size: {size}, Execution time: {t:.8f} seconds")

# Plotting the graph
plt.figure(figsize=(6,4))
plt.plot(input_sizes, execution_times, marker='o', color='red')
plt.title("Logarithmic Time Complexity Example: Binary Search")
plt.xlabel("Input Size (n)")
plt.ylabel("Execution Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# Input size: 10, Execution time: 0.00000405 seconds
# Input size: 100, Execution time: 0.00000310 seconds
# Input size: 1000, Execution time: 0.00000620 seconds
# Input size: 5000, Execution time: 0.00000429 seconds
# Input size: 10000, Execution time: 0.00000763 seconds
# Input size: 50000, Execution time: 0.00000858 seconds

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
#Prob_5 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.Perfect, Vaibhav! Now we’re at Problem 5, where we need an example of log-linear time complexity (O(n log n)).
import matplotlib.pyplot as plt
import random
import time

# Function with log-linear time complexity O(n log n)
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])
    return merge(left, right)

def merge(left, right):
    result = []
    i = j = 0
    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1
    result.extend(left[i:])
    result.extend(right[j:])
    return result

# Test with different input sizes
input_sizes = [10, 100, 1000, 5000, 10000, 20000]
execution_times = []

for size in input_sizes:
    arr = [random.randint(0, 100000) for _ in range(size)]
    start = time.time()
    merge_sort(arr)
    end = time.time()
    execution_times.append(end - start)

# Print results
for size, t in zip(input_sizes, execution_times):
    print(f"Input size: {size}, Execution time: {t:.6f} seconds")

# Plotting the graph
plt.figure(figsize=(6,4))
plt.plot(input_sizes, execution_times, marker='o', color='purple')
plt.title("Log-Linear Time Complexity Example: Merge Sort")
plt.xlabel("Input Size (n)")
plt.ylabel("Execution Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# Input size: 10, Execution time: 0.000027 seconds
# Input size: 100, Execution time: 0.000145 seconds
# Input size: 1000, Execution time: 0.001820 seconds
# Input size: 5000, Execution time: 0.011228 seconds
# Input size: 10000, Execution time: 0.030102 seconds
# Input size: 20000, Execution time: 0.053922 seconds

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import random
import time
import matplotlib.pyplot as plt

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def merge(left, right):
    merged = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            merged.append(left[i])
            i += 1
        else:
            merged.append(right[j])
            j += 1

    merged.extend(left[i:])
    merged.extend(right[j:])
    return merged

input_sizes = [100, 500, 1000, 2000, 4000, 8000]
times = []

for n in input_sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]

    start_time = time.time()
    merge_sort(arr)
    end_time = time.time()

    times.append(end_time - start_time)

plt.figure(figsize=(8, 5))
plt.plot(input_sizes, times, marker='o', linestyle='-', color='purple')
plt.xlabel('Input Size (n)')
plt.ylabel('Time Taken (seconds)')
plt.title('Merge Sort Time Complexity (O(n log n))')
plt.grid(True)
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7 Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example
import random
import time
import matplotlib.pyplot as plt

def merge_sort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left, right)

def merge(left, right):
    merged = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] <= right[j]:
            merged.append(left[i])
            i += 1
        else:
            merged.append(right[j])
            j += 1

    merged.extend(left[i:])
    merged.extend(right[j:])
    return merged

input_sizes = [100, 500, 1000, 2000, 4000, 8000]
times = []

for n in input_sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]
    start_time = time.time()
    merge_sort(arr)
    end_time = time.time()
    times.append(end_time - start_time)

plt.figure(figsize=(8, 5))
plt.plot(input_sizes, times, marker='o', color='purple')
plt.xlabel('Input Size (n)')
plt.ylabel('Time Taken (seconds)')
plt.title('Merge Sort Time Complexity (O(n log n))')
plt.grid(True)
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import matplotlib.pyplot as plt
import math

n = list(range(1, 10))

f_n = [i for i in n]
g_n = [math.log2(i) for i in n]
h_n = [i**2 for i in n]
k_n = [2**i for i in n]

plt.figure(figsize=(8, 5))

plt.plot(n, f_n, label="f(n)=n", color="blue")
plt.plot(n, g_n, label="g(n)=log₂(n)", color="red")
plt.plot(n, h_n, label="h(n)=n²", color="green")
plt.plot(n, k_n, label="k(n)=2ⁿ", color="yellow")

plt.xlabel("Values of n")
plt.ylabel("Time Complexity")
plt.title("Time Complexity Plot")
plt.legend()
plt.grid(True)

plt.show()

# %%
import random
import sys
sys.setrecursionlimit(10000)

max_depth = 0

def quick_sort(arr, depth=1):
    global max_depth
    max_depth = max(max_depth, depth)

    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return (
        quick_sort(left, depth + 1) +
        middle +
        quick_sort(right, depth + 1)
    )


input_sizes = [10, 100, 1000, 10000]

for n in input_sizes:
    max_depth = 0
    arr = [random.randint(1, 100000) for _ in range(n)]
    quick_sort(arr)

    print(f"Input size: {n}")
    print(f"Maximum recursion depth: {max_depth}")
    print(f"log2({n}) ≈ {round((n).bit_length() - 1, 2)}")
    print("-" * 40)
# Out:
# Input size: 10
# Maximum recursion depth: 5
# log2(10) ≈ 3
# ----------------------------------------
# Input size: 100
# Maximum recursion depth: 11
# log2(100) ≈ 6
# ----------------------------------------
# Input size: 1000
# Maximum recursion depth: 22
# log2(1000) ≈ 9
# ----------------------------------------
# Input size: 10000
# Maximum recursion depth: 30
# log2(10000) ≈ 13
# ----------------------------------------
